# %% [markdown]
# ## Task 1 RNN

# %%
# Convert glove text to word2vec format if it does'nt already exist
from os.path import exists
from gensim.scripts.glove2word2vec import glove2word2vec
glove_input_file = 'glove.6B.300d.txt'
word2vec_file = 'glove.6B.300d.txt.word2vec'

if not exists(word2vec_file):
    print("Creating file in glove format")
    glove2word2vec(glove_input_file, word2vec_file)

# %%
import pandas as pd
import numpy as np

# Function to load the training and test datasets
# Returns data in the format x_train, y_train, x_test, y_test
def load_dataset():
    train_df = pd.read_csv('traindrug.csv')
    test_df = pd.read_csv('testdrug.csv')

    x_train = train_df.values[:, 0]
    y_train = train_df.values[:, 1].astype(np.int32)

    x_test = test_df.values[:, 0]
    y_test = test_df.values[:, 1].astype(np.int32)

    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = load_dataset()

# Confirming expected data sizes
print("Length: x_train:", len(x_train))
print("Length: y_train:", len(y_train))
print("Length: x_test:", len(x_test))
print("Length: y_test:", len(y_test))

assert len(x_train) == 1000
assert len(y_train) == 1000
assert len(x_test) == 500
assert len(y_test) == 500
# Out:
# Length: x_train: 1000
# Length: y_train: 1000
# Length: x_test: 500
# Length: y_test: 500

# %%
# Load word to vec glove file 
from gensim.models import KeyedVectors
glove_vectors = KeyedVectors.load_word2vec_format(word2vec_file, binary=False)

# %%
# Setup tokenizer and fit to training data
#  Imports for converting data to tokenized integers for embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=50000)
tokenizer.fit_on_texts(x_train)

train_sequences = tokenizer.texts_to_sequences(x_train)

number_of_words = len(tokenizer.word_index) + 1

# Determine the max word count in a sample in x_train
sentence_word_counts = []
for x in x_train:
    sentence_word_counts.append(len(x.split()))
max_word_count = max(sentence_word_counts) + 10 # Adding more if max_word_count in test is larger 
print("Maximum words in a sentence in x_train:", max_word_count)

# Pad all sequences to the same length
x_train_seq = pad_sequences(sequences=train_sequences, maxlen=max_word_count)

# Also create and pad the sequence for test data
test_sequences = tokenizer.texts_to_sequences(x_test)
x_test_seq = pad_sequences(sequences=test_sequences, maxlen=max_word_count)

# Lastly convert all sequences to a numpy float array
x_train_seq = np.asarray(x_train_seq).astype(np.float32)
x_test_seq = np.asarray(x_test_seq).astype(np.float32)

print(x_train_seq.shape)
# Out:
# Maximum words in a sentence in x_train: 310
# (1000, 310)

# %%
# Define weight matrix for embedding and populate with glove vector at for each word
embedded_weight_matrix = np.zeros((number_of_words, 300))

for word, i in tokenizer.word_index.items():
    if word in glove_vectors:
        embedding_vector = glove_vectors[word]
        embedded_weight_matrix[i] = embedding_vector

# Test the matrix compare word at index 0
print(embedded_weight_matrix.shape)
print(np.array_equal(embedded_weight_matrix[1] ,glove_vectors['i']))
# Out:
# (5626, 300)
# True

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.optimizers import Adam

# Define a model
rnn_model = Sequential()
rnn_model.add(Embedding(input_dim=number_of_words, output_dim=300, weights=[embedded_weight_matrix], input_length=max_word_count, trainable=False))
rnn_model.add(LSTM(64, dropout=0.1, recurrent_dropout=0.1))
rnn_model.add(Dense(128, activation='relu'))
rnn_model.add(Dense(1, kernel_initializer='random_uniform', bias_initializer='zeros'))

opt = Adam(learning_rate=0.001)

rnn_model.compile(optimizer=opt, loss='mean_absolute_error', metrics=['accuracy'])

# Run the model against the computed vectors
epochs = 100
history = rnn_model.fit(x_train_seq, y_train, epochs=epochs, batch_size=32, verbose=1, validation_data=(x_test_seq, y_test))

final_loss, final_acc = rnn_model.evaluate(x_test_seq, y_test)
print("Final accuracy on test: {}".format(final_acc))
print('Final loss on test: ', final_loss)

# Evaluation of softmax approach
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(1,2,1)
plt.plot(range(epochs), history.history['loss'], label='loss')
plt.plot(range(epochs), history.history['val_loss'], label='val_loss')
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Mean Absolute Error")
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 32/32 [==============================] - 19s 518ms/step - loss: 1.0728 - accuracy: 0.2630 - val_loss: 0.7675 - val_accuracy: 0.3280
# Epoch 2/100
# 32/32 [==============================] - 17s 533ms/step - loss: 0.7124 - accuracy: 0.3340 - val_loss: 0.6898 - val_accuracy: 0.3280
# Epoch 3/100
# 32/32 [==============================] - 17s 524ms/step - loss: 0.6814 - accuracy: 0.3340 - val_loss: 0.6860 - val_accuracy: 0.3280
# Epoch 4/100
# 32/32 [==============================] - 17s 516ms/step - loss: 0.6710 - accuracy: 0.3340 - val_loss: 0.6852 - val_accuracy: 0.3280
# Epoch 5/100
# 32/32 [==============================] - 17s 520ms/step - loss: 0.6764 - accuracy: 0.3340 - val_loss: 0.7126 - val_accuracy: 0.3280
# Epoch 6/100
# 32/32 [==============================] - 16s 513ms/step - loss: 0.6592 - accuracy: 0.3340 - val_loss: 0.6918 - val_accuracy: 0.3280
# Epoch 7/100
# 32/32 [==============================] - 16s 514ms/step - loss: 0.6449 - accuracy: 0.3340 - val_loss: 0.6854 - val_accuracy: 0.3280
# Epoch 8/100
# 32/32 [==============================] - 17s 520ms/step - loss: 0.6134 - accuracy: 0.3340 - val_loss: 0.6829 - val_accuracy: 0.3280
# Epoch 9/100
# 32/32 [==============================] - 17s 522ms/step - loss: 0.5883 - accuracy: 0.3340 - val_loss: 0.6902 - val_accuracy: 0.3280
# Epoch 10/100
# 32/32 [==============================] - 16s 512ms/step - loss: 0.5507 - accuracy: 0.3340 - val_loss: 0.6725 - val_accuracy: 0.3280
# Epoch 11/100
# 32/32 [==============================] - 16s 512ms/step - loss: 0.5207 - accuracy: 0.3340 - val_loss: 0.6658 - val_accuracy: 0.3280
# Epoch 12/100
# 32/32 [==============================] - 16s 510ms/step - loss: 0.4944 - accuracy: 0.3340 - val_loss: 0.7006 - val_accuracy: 0.3260
# Epoch 13/100
# 32/32 [==============================] - 16s 498ms/step - loss: 0.4882 - accuracy: 0.3340 - val_loss: 0.6603 - val_accuracy: 0.3280
# Epoch 14/100
# 32/32 [==============================] - 16s 504ms/step - loss: 0.4640 - accuracy: 0.3340 - val_loss: 0.6465 - val_accuracy: 0.3280
# Epoch 15/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.4354 - accuracy: 0.3330 - val_loss: 0.6444 - val_accuracy: 0.3280
# Epoch 16/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.4289 - accuracy: 0.3340 - val_loss: 0.6803 - val_accuracy: 0.3280
# Epoch 17/100
# 32/32 [==============================] - 16s 495ms/step - loss: 0.4533 - accuracy: 0.3340 - val_loss: 0.6534 - val_accuracy: 0.3280
# Epoch 18/100
# 32/32 [==============================] - 16s 498ms/step - loss: 0.3841 - accuracy: 0.3340 - val_loss: 0.6431 - val_accuracy: 0.3280
# Epoch 19/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.3551 - accuracy: 0.3340 - val_loss: 0.6444 - val_accuracy: 0.3280
# Epoch 20/100
# 32/32 [==============================] - 16s 493ms/step - loss: 0.3530 - accuracy: 0.3340 - val_loss: 0.6417 - val_accuracy: 0.3280
# Epoch 21/100
# 32/32 [==============================] - 16s 494ms/step - loss: 0.3254 - accuracy: 0.3340 - val_loss: 0.6345 - val_accuracy: 0.3280
# Epoch 22/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.3279 - accuracy: 0.3340 - val_loss: 0.6517 - val_accuracy: 0.3280
# Epoch 23/100
# 32/32 [==============================] - 16s 494ms/step - loss: 0.2993 - accuracy: 0.3340 - val_loss: 0.6501 - val_accuracy: 0.3280
# Epoch 24/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.2860 - accuracy: 0.3330 - val_loss: 0.6384 - val_accuracy: 0.3280
# Epoch 25/100
# 32/32 [==============================] - 16s 492ms/step - loss: 0.2697 - accuracy: 0.3340 - val_loss: 0.6381 - val_accuracy: 0.3280
# Epoch 26/100
# 32/32 [==============================] - 19s 608ms/step - loss: 0.2673 - accuracy: 0.3340 - val_loss: 0.6526 - val_accuracy: 0.3280
# Epoch 27/100
# 32/32 [==============================] - 19s 583ms/step - loss: 0.2557 - accuracy: 0.3340 - val_loss: 0.6336 - val_accuracy: 0.3280
# Epoch 28/100
# 32/32 [==============================] - 18s 551ms/step - loss: 0.2485 - accuracy: 0.3340 - val_loss: 0.6540 - val_accuracy: 0.3280
# Epoch 29/100
# 32/32 [==============================] - 19s 607ms/step - loss: 0.2491 - accuracy: 0.3340 - val_loss: 0.6417 - val_accuracy: 0.3280
# Epoch 30/100
# 32/32 [==============================] - 18s 550ms/step - loss: 0.2340 - accuracy: 0.3340 - val_loss: 0.6790 - val_accuracy: 0.3280
# Epoch 31/100
# 32/32 [==============================] - 18s 548ms/step - loss: 0.2213 - accuracy: 0.3340 - val_loss: 0.6551 - val_accuracy: 0.3280
# Epoch 32/100
# 32/32 [==============================] - 16s 508ms/step - loss: 0.2152 - accuracy: 0.3340 - val_loss: 0.6714 - val_accuracy: 0.3280
# Epoch 33/100
# 32/32 [==============================] - 17s 533ms/step - loss: 0.2110 - accuracy: 0.3340 - val_loss: 0.6606 - val_accuracy: 0.3280
# Epoch 34/100
# 32/32 [==============================] - 15s 476ms/step - loss: 0.2089 - accuracy: 0.3340 - val_loss: 0.6521 - val_accuracy: 0.3280
# Epoch 35/100
# 32/32 [==============================] - 15s 456ms/step - loss: 0.1894 - accuracy: 0.3340 - val_loss: 0.6495 - val_accuracy: 0.3280
# Epoch 36/100
# 32/32 [==============================] - 14s 451ms/step - loss: 0.1878 - accuracy: 0.3340 - val_loss: 0.6441 - val_accuracy: 0.3280
# Epoch 37/100
# 32/32 [==============================] - 14s 451ms/step - loss: 0.1842 - accuracy: 0.3340 - val_loss: 0.6484 - val_accuracy: 0.3280
# Epoch 38/100
# 32/32 [==============================] - 14s 452ms/step - loss: 0.1814 - accuracy: 0.3340 - val_loss: 0.6506 - val_accuracy: 0.3280
# Epoch 39/100
# 32/32 [==============================] - 14s 451ms/step - loss: 0.1690 - accuracy: 0.3340 - val_loss: 0.6510 - val_accuracy: 0.3280
# Epoch 40/100
# 32/32 [==============================] - 14s 453ms/step - loss: 0.1602 - accuracy: 0.3340 - val_loss: 0.6460 - val_accuracy: 0.3280
# Epoch 41/100
# 32/32 [==============================] - 15s 456ms/step - loss: 0.1613 - accuracy: 0.3340 - val_loss: 0.6500 - val_accuracy: 0.3280
# Epoch 42/100
# 32/32 [==============================] - 15s 460ms/step - loss: 0.1511 - accuracy: 0.3340 - val_loss: 0.6508 - val_accuracy: 0.3280
# Epoch 43/100
# 32/32 [==============================] - 17s 536ms/step - loss: 0.1529 - accuracy: 0.3340 - val_loss: 0.6511 - val_accuracy: 0.3280
# Epoch 44/100
# 32/32 [==============================] - 16s 510ms/step - loss: 0.1563 - accuracy: 0.3340 - val_loss: 0.6555 - val_accuracy: 0.3280
# Epoch 45/100
# 32/32 [==============================] - 16s 490ms/step - loss: 0.1480 - accuracy: 0.3340 - val_loss: 0.6418 - val_accuracy: 0.3280
# Epoch 46/100
# 32/32 [==============================] - 16s 504ms/step - loss: 0.1389 - accuracy: 0.3340 - val_loss: 0.6553 - val_accuracy: 0.3280
# Epoch 47/100
# 32/32 [==============================] - 16s 512ms/step - loss: 0.1503 - accuracy: 0.3340 - val_loss: 0.6556 - val_accuracy: 0.3280
# Epoch 48/100
# 32/32 [==============================] - 17s 520ms/step - loss: 0.1377 - accuracy: 0.3340 - val_loss: 0.6418 - val_accuracy: 0.3280
# Epoch 49/100
# 32/32 [==============================] - 17s 518ms/step - loss: 0.1407 - accuracy: 0.3340 - val_loss: 0.6451 - val_accuracy: 0.3280
# Epoch 50/100
# 32/32 [==============================] - 16s 497ms/step - loss: 0.1343 - accuracy: 0.3340 - val_loss: 0.6586 - val_accuracy: 0.3280
# Epoch 51/100
# 32/32 [==============================] - 16s 514ms/step - loss: 0.1284 - accuracy: 0.3340 - val_loss: 0.6541 - val_accuracy: 0.3280
# Epoch 52/100
# 32/32 [==============================] - 16s 492ms/step - loss: 0.1266 - accuracy: 0.3340 - val_loss: 0.6542 - val_accuracy: 0.3280
# Epoch 53/100
# 32/32 [==============================] - 16s 499ms/step - loss: 0.1374 - accuracy: 0.3340 - val_loss: 0.6463 - val_accuracy: 0.3280
# Epoch 54/100
# 32/32 [==============================] - 16s 493ms/step - loss: 0.1235 - accuracy: 0.3340 - val_loss: 0.6493 - val_accuracy: 0.3280
# Epoch 55/100
# 32/32 [==============================] - 16s 495ms/step - loss: 0.1240 - accuracy: 0.3340 - val_loss: 0.6496 - val_accuracy: 0.3280
# Epoch 56/100
# 32/32 [==============================] - 16s 501ms/step - loss: 0.1200 - accuracy: 0.3340 - val_loss: 0.6473 - val_accuracy: 0.3280
# Epoch 57/100
# 32/32 [==============================] - 16s 498ms/step - loss: 0.1306 - accuracy: 0.3340 - val_loss: 0.6523 - val_accuracy: 0.3280
# Epoch 58/100
# 32/32 [==============================] - 17s 535ms/step - loss: 0.1294 - accuracy: 0.3340 - val_loss: 0.6504 - val_accuracy: 0.3280
# Epoch 59/100
# 32/32 [==============================] - 16s 500ms/step - loss: 0.1203 - accuracy: 0.3340 - val_loss: 0.6404 - val_accuracy: 0.3280
# Epoch 60/100
# 32/32 [==============================] - 16s 499ms/step - loss: 0.1168 - accuracy: 0.3340 - val_loss: 0.6417 - val_accuracy: 0.3280
# Epoch 61/100
# 32/32 [==============================] - 16s 491ms/step - loss: 0.1137 - accuracy: 0.3340 - val_loss: 0.6395 - val_accuracy: 0.3280
# Epoch 62/100
# 32/32 [==============================] - 16s 511ms/step - loss: 0.1094 - accuracy: 0.3340 - val_loss: 0.6543 - val_accuracy: 0.3280
# Epoch 63/100
# 32/32 [==============================] - 16s 511ms/step - loss: 0.1151 - accuracy: 0.3340 - val_loss: 0.6543 - val_accuracy: 0.3280
# Epoch 64/100
# 32/32 [==============================] - 16s 497ms/step - loss: 0.1200 - accuracy: 0.3340 - val_loss: 0.6405 - val_accuracy: 0.3280
# Epoch 65/100
# 32/32 [==============================] - 16s 502ms/step - loss: 0.1235 - accuracy: 0.3340 - val_loss: 0.6361 - val_accuracy: 0.3280
# Epoch 66/100
# 32/32 [==============================] - 16s 502ms/step - loss: 0.1138 - accuracy: 0.3340 - val_loss: 0.6382 - val_accuracy: 0.3280
# Epoch 67/100
# 32/32 [==============================] - 16s 488ms/step - loss: 0.1106 - accuracy: 0.3340 - val_loss: 0.6408 - val_accuracy: 0.3280
# Epoch 68/100
# 32/32 [==============================] - 16s 496ms/step - loss: 0.1059 - accuracy: 0.3340 - val_loss: 0.6398 - val_accuracy: 0.3280
# Epoch 69/100
# 32/32 [==============================] - 15s 480ms/step - loss: 0.1030 - accuracy: 0.3340 - val_loss: 0.6412 - val_accuracy: 0.3280
# Epoch 70/100
# 32/32 [==============================] - 15s 474ms/step - loss: 0.1054 - accuracy: 0.3340 - val_loss: 0.6388 - val_accuracy: 0.3280
# Epoch 71/100
# 32/32 [==============================] - 15s 472ms/step - loss: 0.1036 - accuracy: 0.3340 - val_loss: 0.6403 - val_accuracy: 0.3280
# Epoch 72/100
# 32/32 [==============================] - 15s 474ms/step - loss: 0.0965 - accuracy: 0.3340 - val_loss: 0.6398 - val_accuracy: 0.3280
# Epoch 73/100
# 32/32 [==============================] - 15s 468ms/step - loss: 0.1012 - accuracy: 0.3340 - val_loss: 0.6433 - val_accuracy: 0.3280
# Epoch 74/100
# 32/32 [==============================] - 15s 471ms/step - loss: 0.1069 - accuracy: 0.3340 - val_loss: 0.6401 - val_accuracy: 0.3280
# Epoch 75/100
# 32/32 [==============================] - 15s 468ms/step - loss: 0.0941 - accuracy: 0.3340 - val_loss: 0.6365 - val_accuracy: 0.3280
# Epoch 76/100
# 32/32 [==============================] - 15s 471ms/step - loss: 0.0960 - accuracy: 0.3340 - val_loss: 0.6386 - val_accuracy: 0.3280
# Epoch 77/100
# 32/32 [==============================] - 15s 469ms/step - loss: 0.1001 - accuracy: 0.3340 - val_loss: 0.6399 - val_accuracy: 0.3280
# Epoch 78/100
# 32/32 [==============================] - 15s 474ms/step - loss: 0.0983 - accuracy: 0.3340 - val_loss: 0.6419 - val_accuracy: 0.3280
# Epoch 79/100
# 32/32 [==============================] - 15s 468ms/step - loss: 0.1060 - accuracy: 0.3340 - val_loss: 0.6369 - val_accuracy: 0.3280
# Epoch 80/100
# 32/32 [==============================] - 15s 466ms/step - loss: 0.0996 - accuracy: 0.3340 - val_loss: 0.6377 - val_accuracy: 0.3280
# Epoch 81/100
# 32/32 [==============================] - 15s 467ms/step - loss: 0.1077 - accuracy: 0.3340 - val_loss: 0.6380 - val_accuracy: 0.3280
# Epoch 82/100
# 32/32 [==============================] - 15s 468ms/step - loss: 0.0950 - accuracy: 0.3340 - val_loss: 0.6382 - val_accuracy: 0.3280
# Epoch 83/100
# 32/32 [==============================] - 15s 460ms/step - loss: 0.0892 - accuracy: 0.3340 - val_loss: 0.6388 - val_accuracy: 0.3280
# Epoch 84/100
# 32/32 [==============================] - 15s 458ms/step - loss: 0.0883 - accuracy: 0.3340 - val_loss: 0.6274 - val_accuracy: 0.3280
# Epoch 85/100
# 32/32 [==============================] - 14s 454ms/step - loss: 0.0926 - accuracy: 0.3340 - val_loss: 0.6286 - val_accuracy: 0.3280
# Epoch 86/100
# 32/32 [==============================] - 15s 459ms/step - loss: 0.0911 - accuracy: 0.3340 - val_loss: 0.6324 - val_accuracy: 0.3280
# Epoch 87/100
# 32/32 [==============================] - 14s 451ms/step - loss: 0.0901 - accuracy: 0.3340 - val_loss: 0.6325 - val_accuracy: 0.3280
# Epoch 88/100
# 32/32 [==============================] - 15s 478ms/step - loss: 0.0817 - accuracy: 0.3340 - val_loss: 0.6278 - val_accuracy: 0.3280
# Epoch 89/100
# 32/32 [==============================] - 15s 466ms/step - loss: 0.0919 - accuracy: 0.3340 - val_loss: 0.6382 - val_accuracy: 0.3280
# Epoch 90/100
# 32/32 [==============================] - 14s 451ms/step - loss: 0.0868 - accuracy: 0.3340 - val_loss: 0.6360 - val_accuracy: 0.3280
# Epoch 91/100
# 32/32 [==============================] - 14s 453ms/step - loss: 0.0961 - accuracy: 0.3340 - val_loss: 0.6394 - val_accuracy: 0.3280
# Epoch 92/100
# 32/32 [==============================] - 15s 457ms/step - loss: 0.0909 - accuracy: 0.3340 - val_loss: 0.6266 - val_accuracy: 0.3280
# Epoch 93/100
# 32/32 [==============================] - 15s 455ms/step - loss: 0.0850 - accuracy: 0.3340 - val_loss: 0.6307 - val_accuracy: 0.3280
# Epoch 94/100
# 32/32 [==============================] - 15s 459ms/step - loss: 0.0882 - accuracy: 0.3340 - val_loss: 0.6346 - val_accuracy: 0.3280
# Epoch 95/100
# 32/32 [==============================] - 15s 460ms/step - loss: 0.0969 - accuracy: 0.3340 - val_loss: 0.6356 - val_accuracy: 0.3280
# Epoch 96/100
# 32/32 [==============================] - 15s 460ms/step - loss: 0.0822 - accuracy: 0.3340 - val_loss: 0.6327 - val_accuracy: 0.3280
# Epoch 97/100
# 32/32 [==============================] - 15s 464ms/step - loss: 0.0880 - accuracy: 0.3340 - val_loss: 0.6310 - val_accuracy: 0.3280
# Epoch 98/100
# 32/32 [==============================] - 15s 471ms/step - loss: 0.0865 - accuracy: 0.3340 - val_loss: 0.6394 - val_accuracy: 0.3280
# Epoch 99/100
# 32/32 [==============================] - 15s 470ms/step - loss: 0.0865 - accuracy: 0.3340 - val_loss: 0.6319 - val_accuracy: 0.3280
# Epoch 100/100
# 32/32 [==============================] - 15s 474ms/step - loss: 0.0813 - accuracy: 0.3340 - val_loss: 0.6321 - val_accuracy: 0.3280
# 16/16 [==============================] - 1s 77ms/step - loss: 0.6321 - accuracy: 0.3280
# Final accuracy on test: 0.328000009059906
# Final loss on test:  0.6321184039115906
